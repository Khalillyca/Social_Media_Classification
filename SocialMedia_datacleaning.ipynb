# %%
import psycopg2, traceback
import io
import pandas as pd
from datetime import date, datetime
from decimal import Decimal

import warnings 
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
from glob import glob

# %%
import re

emoji_pattern = re.compile(
    "["
    "\U0001F600-\U0001F64F"  # emoticons
    "\U0001F300-\U0001F5FF"  # symbols & pictographs
    "\U0001F680-\U0001F6FF"  # transport & map
    "\U0001F1E0-\U0001F1FF"  # flags
    "\U00002700-\U000027BF"  # dingbats
    "\U0001F900-\U0001F9FF"  # supplemental symbols
    "\U0001FA00-\U0001FAFF"  # extended symbols
    "]+",
    flags=re.UNICODE
)

# %%
from glob import glob
import pandas as pd

folder_path = r"C:\Users\Moha8550\OneDrive - Lyca Group\Desktop\SocialMedia_datapreprocessing_folder\concatfiles"

files = glob(f"{folder_path}\\*.xlsx")

print("Files found:", files)
print("Number of files:", len(files))
# Out:
# Files found: ['C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Belgium(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\France(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Germany(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Italy(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Netherland(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Portugal(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\Uganda(13 Feb TO 19 Feb).xlsx', 'C:\\Users\\Moha8550\\OneDrive - Lyca Group\\Desktop\\SocialMedia_datapreprocessing_folder\\concatfiles\\UK_ (13 Feb TO 19 Feb).xlsx']
# Number of files: 8
